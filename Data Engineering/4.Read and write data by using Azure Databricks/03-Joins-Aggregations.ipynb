# %% [markdown]
# # Aggregations and JOINs
# Apache Spark&trade; and Databricks&reg; allow you to create on-the-fly data lakes.

# %% [markdown]
# ### Getting Started
#
# Run the following cell to configure our "classroom."

# %%
# %run "./Includes/Classroom-Setup"

# %% [markdown]
# -sandbox
# ## Basic Aggregations
#
# Using <a "https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.functions" target="_blank">built-in Spark functions</a>, you can aggregate data in various ways.
#
# Run the cell below to compute the average of all salaries in the people DataFrame.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> By default, you get a floating point value.

# %%
peopleDF = spark.read.parquet("/mnt/training/dataframes/people-10m.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import avg
avgSalaryDF = peopleDF.select(avg("salary").alias("averageSalary"))

avgSalaryDF.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+
# averageSalary|
# +-------------+
# 72633.0076033|
# +-------------+
#
# </div>

# %% [markdown]
# Convert that value to an integer using the `round()` function. See
# <a href "https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.functions$" class="text-info">the documentation for <tt>round()</tt></a>
# for more details.

# %%
from pyspark.sql.functions import round
roundedAvgSalaryDF = avgSalaryDF.select(round("averageSalary").alias("roundedAverageSalary"))

roundedAvgSalaryDF.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
# roundedAverageSalary|
# +--------------------+
#              72633.0|
# +--------------------+
#
# </div>

# %% [markdown]
# In addition to the average salary, what are the maximum and minimum salaries?

# %%
from pyspark.sql.functions import min, max
salaryDF = peopleDF.select(max("salary").alias("max"), min("salary").alias("min"), round(avg("salary")).alias("averageSalary"))

salaryDF.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+------+-------------+
#    max|   min|averageSalary|
# +------+------+-------------+
# 180841|-26884|      72633.0|
# +------+------+-------------+
#
# </div>

# %% [markdown]
# ## Joining Two Data Sets
#
# Correlate the data in two data sets using a DataFrame join.
#
# The `people` data set has 10 million names in it.
#
# > How many of the first names appear in Social Security data files?
#
# To find out, use the Social Security data set with first name popularity data from the United States Social Security Administration.
#
# For every year from 1880 to 2014, `dbfs:/mnt/training/ssn/names-1880-2016.parquet/` lists the first names of people born in that year, their gender, and the total number of people given that name.
#
# By joining the `people` data set with `names-1880-2016`, weed out the names that aren't represented in the Social Security data.
#
# (In a real application, you might use a join like this to filter out bad data.)

# %% [markdown]
# Start by taking a look at what the social security data set looks like. Each year is its own directory.

# %%
# %fs ls dbfs:/mnt/training/ssn/names-1880-2016.parquet/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1880/</td><td>year=1880/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1881/</td><td>year=1881/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1882/</td><td>year=1882/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1883/</td><td>year=1883/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1884/</td><td>year=1884/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1885/</td><td>year=1885/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1886/</td><td>year=1886/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1887/</td><td>year=1887/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1888/</td><td>year=1888/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1889/</td><td>year=1889/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1890/</td><td>year=1890/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1891/</td><td>year=1891/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1892/</td><td>year=1892/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1893/</td><td>year=1893/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1894/</td><td>year=1894/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1895/</td><td>year=1895/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1896/</td><td>year=1896/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1897/</td><td>year=1897/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1898/</td><td>year=1898/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1899/</td><td>year=1899/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1900/</td><td>year=1900/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1901/</td><td>year=1901/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1902/</td><td>year=1902/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1903/</td><td>year=1903/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1904/</td><td>year=1904/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1905/</td><td>year=1905/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1906/</td><td>year=1906/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1907/</td><td>year=1907/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1908/</td><td>year=1908/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1909/</td><td>year=1909/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1910/</td><td>year=1910/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1911/</td><td>year=1911/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1912/</td><td>year=1912/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=1913/</td><td>year=1913/</td><td>0</td></tr><tr><td>dbfs:/mnt/training/ssn/names-1880-2016.parquet/year=
tr><tr><td>Jasmine</td><td>F</td><td>5518</td><td>2008</td></tr><tr><td>Audrey</td><td>F</td><td>5438</td><td>2008</td></tr><tr><td>Katherine</td><td>F</td><td>5344</td><td>2008</td></tr><tr><td>Morgan</td><td>F</td><td>5334</td><td>2008</td></tr><tr><td>Brooklyn</td><td>F</td><td>5309</td><td>2008</td></tr><tr><td>Destiny</td><td>F</td><td>5304</td><td>2008</td></tr><tr><td>Sydney</td><td>F</td><td>5259</td><td>2008</td></tr><tr><td>Alexa</td><td>F</td><td>5223</td><td>2008</td></tr><tr><td>Kylie</td><td>F</td><td>5190</td><td>2008</td></tr><tr><td>Brooke</td><td>F</td><td>5180</td><td>2008</td></tr><tr><td>Kaitlyn</td><td>F</td><td>5115</td><td>2008</td></tr><tr><td>Evelyn</td><td>F</td><td>5098</td><td>2008</td></tr><tr><td>Layla</td><td>F</td><td>4929</td><td>2008</td></tr><tr><td>Madeline</td><td>F</td><td>4817</td><td>2008</td></tr><tr><td>Kimberly</td><td>F</td><td>4809</td><td>2008</td></tr><tr><td>Zoe</td><td>F</td><td>4781</td><td>2008</td></tr><tr><td>Jessica</td><td>F</td><td>4734</td><td>2008</td></tr><tr><td>Peyton</td><td>F</td><td>4731</td><td>2008</td></tr><tr><td>Alexandra</td><td>F</td><td>4609</td><td>2008</td></tr><tr><td>Claire</td><td>F</td><td>4598</td><td>2008</td></tr><tr><td>Maria</td><td>F</td><td>4584</td><td>2008</td></tr><tr>< ...

# %% [markdown]
# Next, with a quick count of distinct names, get an idea of how many distinct names there are in each of the tables.
#
# DataFrames have a `distinct` method just for this purpose.

# %%
peopleDistinctNamesDF = peopleDF.select("firstName").distinct()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
peopleDistinctNamesDF.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">7</span><span class="ansired">]: </span>5113
# </div>

# %% [markdown]
# -sandbox
# In preparation for the join, let's rename the `firstName` column to `ssaFirstName` in the Social Security DataFrame.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> Question to ponder: why would we want to do this?

# %%
ssaDistinctNamesDF = ssaDF.select("firstName").withColumnRenamed("firstName",'ssaFirstName').distinct()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Count how many distinct names in the Social Security DataFrame.

# %%
ssaDistinctNamesDF.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">10</span><span class="ansired">]: </span>96174
# </div>

# %% [markdown]
# Now join the two DataFrames.

# %%
from pyspark.sql.functions import col, desc
joinedDF = peopleDistinctNamesDF.join(ssaDistinctNamesDF, col("firstName") == col("ssaFirstName"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# How many are there?

# %%
joinedDF.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>5096
# </div>

# %% [markdown]
# -sandbox
# ## Exercise 1
#
# In the tables above, some of the salaries in the `peopleDF` DataFrame are negative.
#
# These salaries represent bad data.
#
# Your job is to convert all the negative salaries to positive ones, and then sort the top 20 people by their salary.
#
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** See the Apache Spark documentation, <a href="https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.functions$" target="_blank">built-in functions</a>.

# %% [markdown]
# ### Step 1
# Create a DataFrame`PeopleWithFixedSalariesDF`, where all the negative salaries have been converted to positive numbers.

# %%
display(peopleWithFixedSalariesDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
><td>29940</td></tr><tr><td>50566</td></tr><tr><td>92080</td></tr><tr><td>71097</td></tr><tr><td>60976</td></tr><tr><td>86631</td></tr><tr><td>85131</td></tr><tr><td>96990</td></tr><tr><td>100606</td></tr><tr><td>61528</td></tr><tr><td>97006</td></tr><tr><td>73373</td></tr><tr><td>56315</td></tr><tr><td>26313</td></tr><tr><td>56297</td></tr><tr><td>94023</td></tr><tr><td>95660</td></tr><tr><td>52303</td></tr><tr><td>105570</td></tr><tr><td>88873</td></tr><tr><td>60213</td></tr><tr><td>47976</td></tr><tr><td>86504</td></tr><tr><td>83889</td></tr><tr><td>89491</td></tr><tr><td>83640</td></tr><tr><td>61072</td></tr><tr><td>76254</td></tr><tr><td>95595</td></tr><tr><td>108406</td></tr><tr><td>73100</td></tr><tr><td>49059</td></tr><tr><td>30496</td></tr><tr><td>95121</td></tr><tr><td>67650< ...

# %%
# TODO

from pyspark.sql.functions import abs
peopleWithFixedSalariesDF = peopleDF.select(abs(col("salary")).alias("salary"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.

belowZero = peopleWithFixedSalariesDF.filter(peopleWithFixedSalariesDF["salary"] < 0).count()
print(belowZero)
#dbTest("DF-L3-belowZero", 0, belowZero)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0
# Tests passed!
# </div>

# %% [markdown]
# ### Step 2
#
# Starting with the `peopleWithFixedSalariesDF` DataFrame, create another DataFrame called `PeopleWithFixedSalariesSortedDF` where:
# 0. The data set has been reduced to the first 20 records.
# 0. The records are sorted by the column `salary` in ascending order.

# %%
# TODO
peopleWithFixedSalariesSortedDF = peopleWithFixedSalariesDF.sort(desc("salary")).limit(20)
display(peopleWithFixedSalariesSortedDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>salary</th></tr></thead><tbody><tr><td>180841</td></tr><tr><td>173969</td></tr><tr><td>170562</td></tr><tr><td>170371</td></tr><tr><td>169899</td></tr><tr><td>168966</td></tr><tr><td>168650</td></tr><tr><td>168153</td></tr><tr><td>167985</td></tr><tr><td>166391</td></tr><tr><td>166324</td></tr><tr><td>166254</td></tr><tr><td>166182</td></tr><tr><td>165757</td></tr><tr><td>165467</td></tr><tr><td>164624</td></tr><tr><td>164363</td></tr><tr><td>164352</td></tr><tr><td>164254</td></tr><tr><td>164039</td></tr></tbody></table></div>

# %%
# TEST - Run this cell to test your solution.

resultsDF = peopleWithFixedSalariesSortedDF.select("salary")
print(resultsDF.count())
#dbTest("DF-L3-count", 20, resultsDF.count())

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">20
# Tests passed!
# </div>

# %%
# TEST - Run this cell to test your solution.

from pyspark.sql import Row

results = resultsDF.collect()

dbTest("DF-L3-fixedSalaries-0", Row(salary=2), results[0])
dbTest("DF-L3-fixedSalaries-1", Row(salary=3), results[1])
dbTest("DF-L3-fixedSalaries-2", Row(salary=4), results[2])

dbTest("DF-L3-fixedSalaries-10", Row(salary=19), results[10])
dbTest("DF-L3-fixedSalaries-11", Row(salary=19), results[11])
dbTest("DF-L3-fixedSalaries-12", Row(salary=20), results[12])

dbTest("DF-L3-fixedSalaries-17", Row(salary=28), results[17])
dbTest("DF-L3-fixedSalaries-18", Row(salary=30), results[18]) 
dbTest("DF-L3-fixedSalaries-19", Row(salary=31), results[19]) 

print("Tests passed!")

# %% [markdown]
# ## Exercise 2
#
# As a refinement, assume all salaries under $20,000 represent bad rows and filter them out.
#
# Additionally, categorize each person's salary into $10K groups.

# %% [markdown]
# ### Step 1
#  Starting with the `peopleWithFixedSalariesDF` DataFrame, create a DataFrame called `peopleWithFixedSalaries20KDF` where:
# 0. The data set excludes all records where salaries are below $20K.
# 0. The data set includes a new column called `salary10k`, that should be the salary in groups of 10,000. For example:
#   * A salary of 23,000 should report a value of "2".
#   * A salary of 57,400 should report a value of "6".
#   * A salary of 1,231,375 should report a value of "123".

# %%
# TODO
peopleWithFixedSalaries20KDF = peopleWithFixedSalariesDF.filter("salary >= 20000").select("salary", round(col("salary")/10000).alias("salary10k"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(peopleWithFixedSalaries20KDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>salary</th><th>salary10k</th></tr></thead><tbody><tr><td>56172</td><td>6.0</td></tr><tr><td>40203</td><td>4.0</td></tr><tr><td>53417</td><td>5.0</td></tr><tr><td>94727</td><td>9.0</td></tr><tr><td>79908</td><td>8.0</td></tr><tr><td>64652</td><td>6.0</td></tr><tr><td>38195</td><td>4.0</td></tr><tr><td>102053</td><td>10.0</td></tr><tr><td>91294</td><td>9.0</td></tr><tr><td>56521</td><td>6.0</td></tr><tr><td>90920</td><td>9.0</td></tr><tr><td>90634</td><td>9.0</td></tr><tr><td>93162</td><td>9.0</td></tr><tr><td>38859</td><td>4.0</td></tr><tr><td>76220</td><td>8.0</td></tr><tr><td>75050</td><td>8.0</td></tr><tr><td>62814</td><td>6.0</td></tr><tr><td>71350</td><td>7.0</td></tr><tr><td>60600</td><td>6.0</td></tr><tr><td>51071</td><td>5.0</td></tr><tr><td>101046</td><td>10.0</td></tr><tr><td>98588</td><td>10.0</td></tr><tr><td>60449</td><td>6.0</td></tr><tr><td>83728</td><td>8.0</td></tr><tr><td>73060</td><td>7.0</td></tr><tr><td>105270</td><td>11.0</td></tr><tr><td>38186</td><td>4.0</td></tr><tr><td>67310</td><td>7.0</td></tr><tr><td>107411</td><td>11.0</td></tr><tr><td>67250</td><td>7.0</td></tr><tr><td>80919</td><td>8.0</td></tr><tr><td>60857</td><td>6.0</td></tr><tr><td>58615</td><td>6.0</td></tr><tr><td>57712</td><td>6.0</td></tr><tr><td>91772</td><td>9.0</td></tr><tr><td>92152</td><td>9.0</td></tr><tr><td>58131</td><td>6.0</td></tr><tr><td>82412</td><td>8.0</td></tr><tr><td>101601</td><td>10.0</td></tr><tr><td>89151</td><td>9.0</td></tr><tr><td>98256</td><td>10.0</td></tr><tr><td>46945</td><td>5.0</td></tr><tr><td>115410</td><td>12.0</td></tr><tr><td>89747</td><td>9.0</td></tr><tr><td>87159</td><td>9.0</td></tr><tr><td>98072</td><td>10.0</td></tr><tr><td>55780</td><td>6.0</td></tr><tr><td>52549</td><td>5.0</td></tr><tr><td>73811</td><td>7.0</td></tr><tr><td>115845</td><td>12.0</td></tr><tr><td>112662</td><td>11.0</td></tr><tr><td>66712</td><td>7.0</td></tr><tr><td>74767</td><td>7.0</td></tr><tr><td>67801</td><td>7.0</td></tr><tr><td>104262</td><td>10.0</td></tr><tr><td>48781</td><td>5.0</td></tr><tr><td>111979</td><td>11.0</td></tr><tr><td>47190</td><td>5.0</td></tr><tr><td>52410</td><td>5.0</td></tr><tr><td>72745</td><td>7.0</td></tr><tr><td>63563</td><td>6.0</td></tr><tr><td>80113</td><td>8.0</td></tr><tr><td>61310</td><td>6.0</td></tr><tr><td>65836</td><td>7.0</td></tr><tr><td>32795</td><td>3.0</td></tr><tr><td>66115</td><td>7.0</td></tr><tr><td>52476</td><td>5.0</td></tr><tr><td>92341</td><td>9.0</td></tr><tr><td>53715</td><td>5.0</td></tr><tr><td>73754</td><td>7.0</td></tr><tr><td>77925</td><td>8.0</td></tr><tr><td>114348</td><td>11.0</td></tr><tr><td>87593</td><td>9.0</td></tr><tr><td>57255</td><td>6.0</td></tr><tr><td>96490</td><td>10.0</td></tr><tr><td>57409</td><td>6.0</td></tr><tr><td>72379</td><td>7.0</td></tr><tr><td>83764</td><td>8.0</td></tr><tr><td>93416</td><td>9.0</td></tr><tr><td>74484</td><td>7.0</td></tr><tr><td>90966</td><td>9.0</td></tr><tr><td>109293</td><td>11.0</td></tr><tr><td>134393</td><td>13.0</td></tr><tr><td>63879</td><td>6.0</td></tr><tr><td>82866</td><td>8.0</td></tr><tr><td>80696</td><td>8.0</td></tr><tr><td>78464</td><td>8.0</td></tr><tr><td>70873</td><td>7.0</td></tr><tr><td>61597</td><td>6.0</td></tr><tr><td>34053</td><td>3.0</td></tr><tr><td>53763</td><td>5.0</td></tr><tr><td>62846</td><td>6.0</td></tr><tr><td>63075</td><td>6.0</td></tr><tr><td>100950</td><td>10.0</td></tr><tr><td>92524</td><td>9.0</td></tr><tr><td>47349</td><td>5.0</td></tr><tr><td>84084</td><td>8.0</td></tr><tr><td>65425</td><td>7.0</td></tr><tr><td>76773</td><td>8.0</td></tr><tr><td>66481</td><td>7.0</td></tr><tr><td>67397</td><td>7.0</td></tr><tr><td>103530</td><td>10.0</td></tr><tr><td>74993</td><td>7.0</td></tr><tr><td>63044</td><td>6.0</td></tr><tr><td>63493</td><td>6.0</td></tr><tr><td>75298</td><td>8.0</td></tr><tr><td>78894</td><td>8.0</td></tr><tr><td>70683</td><td>7.0</td></tr><tr><td>65276</td> ...

# %%
# TEST - Run this cell to test your solution.

below20K = peopleWithFixedSalaries20KDF.filter("salary < 20000").count()
print(below20K)
 
#dbTest("DF-L3-count-salaries", 0, below20K)  

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0
# Tests passed!
# </div>

# %%
# TEST - Run this cell to test your solution.

from pyspark.sql.functions import count
results = (peopleWithFixedSalaries20KDF 
  .select("salary10k") 
  .groupBy("salary10k") 
  .agg(count("*").alias("total")) 
  .orderBy("salary10k") 
  .limit(5) 
  .collect()
)
display(results)
#dbTest("DF-L3-countSalaries-0", Row(salary10k=2.0, total=43792), results[0])
#dbTest("DF-L3-countSalaries-1", Row(salary10k=3.0, total=212630), results[1])
#dbTest("DF-L3-countSalaries-2", Row(salary10k=4.0, total=536536), results[2])
#dbTest("DF-L3-countSalaries-3", Row(salary10k=5.0, total=1055261), results[3])
#dbTest("DF-L3-countSalaries-4", Row(salary10k=6.0, total=1623248), results[4])

print("Tests passed!")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>salary10k</th><th>total</th></tr></thead><tbody><tr><td>2.0</td><td>43792</td></tr><tr><td>3.0</td><td>212630</td></tr><tr><td>4.0</td><td>536536</td></tr><tr><td>5.0</td><td>1055261</td></tr><tr><td>6.0</td><td>1623248</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 3
#
# Using the `peopleDF` DataFrame, count the number of females named Caren who were born before March 1980.

# %% [markdown]
# ### Step 1
#
# Starting with `peopleDF`, create a DataFrame called `carensDF` where:
# 0. The result set has a single record.
# 0. The data set has a single column named `total`.
# 0. The result counts only
#   * Females (`gender`)
#   * First Name is "Caren" (`firstName`)
#   * Born before March 1980 (`birthDate`)

# %%
display(peopleDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>firstName</th><th>middleName</th><th>lastName</th><th>gender</th><th>birthDate</th><th>ssn</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Pennie</td><td>Carry</td><td>Hirschmann</td><td>F</td><td>1955-07-02T04:00:00.000+0000</td><td>981-43-9345</td><td>56172</td></tr><tr><td>2</td><td>An</td><td>Amira</td><td>Cowper</td><td>F</td><td>1992-02-08T05:00:00.000+0000</td><td>978-97-8086</td><td>40203</td></tr><tr><td>3</td><td>Quyen</td><td>Marlen</td><td>Dome</td><td>F</td><td>1970-10-11T04:00:00.000+0000</td><td>957-57-8246</td><td>53417</td></tr><tr><td>4</td><td>Coralie</td><td>Antonina</td><td>Marshal</td><td>F</td><td>1990-04-11T04:00:00.000+0000</td><td>963-39-4885</td><td>94727</td></tr><tr><td>5</td><td>Terrie</td><td>Wava</td><td>Bonar</td><td>F</td><td>1980-01-16T05:00:00.000+0000</td><td>964-49-8051</td><td>79908</td></tr><tr><td>6</td><td>Chassidy</td><td>Concepcion</td><td>Bourthouloume</td><td>F</td><td>1990-11-24T05:00:00.000+0000</td><td>954-59-9172</td><td>64652</td></tr><tr><td>7</td><td>Geri</td><td>Tambra</td><td>Mosby</td><td>F</td><td>1970-12-19T05:00:00.000+0000</td><td>968-16-4020</td><td>38195</td></tr><tr><td>8</td><td>Patria</td><td>Nancy</td><td>Arstall</td><td>F</td><td>1985-01-02T05:00:00.000+0000</td><td>984-76-3770</td><td>102053</td></tr><tr><td>9</td><td>Terese</td><td>Alfredia</td><td>Tocque</td><td>F</td><td>1967-11-17T05:00:00.000+0000</td><td>967-48-7309</td><td>91294</td></tr><tr><td>10</td><td>Wava</td><td>Lyndsey</td><td>Jeandon</td><td>F</td><td>1963-12-30T05:00:00.000+0000</td><td>997-82-2946</td><td>56521</td></tr><tr><td>11</td><td>Sophie</td><td>Emerita</td><td>Hearn</td><td>F</td><td>1979-09-17T04:00:00.000+0000</td><td>977-66-4483</td><td>90920</td></tr><tr><td>12</td><td>Jodie</td><td>Tabetha</td><td>Laneham</td><td>F</td><td>1959-01-31T05:00:00.000+0000</td><td>923-24-9769</td><td>90634</td></tr><tr><td>13</td><td>Marietta</td><td>Mandi</td><td>Yansons</td><td>F</td><td>1974-02-19T04:00:00.000+0000</td><td>900-34-8083</td><td>93162</td></tr><tr><td>14</td><td>Caridad</td><td>Maire</td><td>Snelle</td><td>F</td><td>1960-09-26T04:00:00.000+0000</td><td>992-11-7062</td><td>38859</td></tr><tr><td>15</td><td>Yasmine</td><td>Meg</td><td>Edworthye</td><td>F</td><td>1960-01-29T05:00:00.000+0000</td><td>922-12-9862</td><td>76220</td></tr><tr><td>16</td><td>Chan</td><td>Jani</td><td>Hartas</td><td>F</td><td>1986-12-05T05:00:00.000+0000</td><td>995-51-3115</td><td>75050</td></tr><tr><td>17</td><td>Evangeline</td><td>Wanetta</td><td>Casserley</td><td>F</td><td>1961-09-29T04:00:00.000+0000</td><td>926-61-3526</td><td>62814</td></tr><tr><td>18</td><td>Elnora</td><td>Kecia</td><td>Lipman</td><td>F</td><td>1980-02-14T05:00:00.000+0000</td><td>950-23-9739</td><td>71350</td></tr><tr><td>19</td><td>Adelle</td><td>Kathyrn</td><td>Grigoriev</td><td>F</td><td>1978-11-14T05:00:00.000+0000</td><td>923-23-5984</td><td>60600</td></tr><tr><td>20</td><td>Mica</td><td>Zandra</td><td>Challens</td><td>F</td><td>1973-11-24T05:00:00.000+0000</td><td>918-66-1232</td><td>51071</td></tr><tr><td>21</td><td>Sarah</td><td>Nickie</td><td>Sadgrove</td><td>F</td><td>1990-11-07T05:00:00.000+0000</td><td>913-18-2717</td><td>101046</td></tr><tr><td>22</td><td>Robbin</td><td>Leeanne</td><td>Sallnow</td><td>F</td><td>1958-12-16T05:00:00.000+0000</td><td>938-88-6975</td><td>98588</td></tr><tr><td>23</td><td>Caroyln</td><td>Mamie</td><td>Cardon</td><td>F</td><td>1994-05-15T04:00:00.000+0000</td><td>927-52-5062</td><td>60449</td></tr><tr><td>24</td><td>Penni</td><td>Stevie</td><td>Searby</td><td>F</td><td>1955-03-23T05:00:00.000+0000</td><td>951-65-9959</td><td>83728</td></tr><tr><td>25</td><td>Yesenia</td><td>Eileen</td><td>Goldring</td><td>F</td><td>1997-07-09T04:00:00.000+0000</td><td>920-71-3216</td><td>73060</td></tr><tr><td>26</td><td>Frankie</td><td>Jovan</td><td>Lydall</td><td>F</td><td ...

# %%
# TODO
from pyspark.sql.functions import year
carensDF = peopleDF.filter("gender='F'").filter("firstName='Caren'").filter(year("birthDate")<1980).agg(count("*").alias("total"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.

rows = carensDF.collect()
print(len(rows))
print(rows[0])
#dbTest("DF-L3-carens-len", 1, len(rows))
#dbTest("DF-L3-carens-total", Row(total=750), rows[0])

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1
# Row(total=746)
# Tests passed!
# </div>

# %% [markdown]
# ## Review Questions
# **Q:** What is the DataFrame equivalent of the SQL statement `SELECT count(*) AS total`
# **A:** ```.agg(count("*").alias("total"))```
#
# **Q:** What is the DataFrame equivalent of the SQL statement
# ```SELECT firstName FROM PeopleDistinctNames INNER JOIN SSADistinctNames ON firstName = ssaFirstName```
# **A:**
# `peopleDistinctNamesDF.join(ssaDistinctNamesDF, peopleDistinctNamesDF(col("firstName")) == col("ssaFirstName"))`

# %% [markdown]
# ## Next Steps
#
# * Do the [Challenge Exercise]($./Optional/03-Joins-Aggregations).
# * Start the next lesson, [Accessing Data]($./04-Accessing-Data).

# %% [markdown]
# ## Additional Topics & Resources
#
# * <a href="http://spark.apache.org/docs/latest/sql-programming-guide.html" target="_blank">Spark SQL, DataFrames and Datasets Guide</a>
# * <a href="https://databricks.com/blog/2017/08/31/cost-based-optimizer-in-apache-spark-2-2.html" target="_blank">Cost-based Optimizer in Apache Spark 2.2</a>
