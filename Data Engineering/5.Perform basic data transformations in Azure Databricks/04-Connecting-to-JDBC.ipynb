# %% [markdown]
# # Connecting to JDBC
#
# Apache Spark&trade; and Azure Databricks&reg; allow you to connect to a number of data stores using JDBC.

# %% [markdown]
# -sandbox
# ## Java Database Connectivity
#
# Java Database Connectivity (JDBC) is an application programming interface (API) that defines database connections in Java environments.  Spark is written in Scala, which runs on the Java Virtual Machine (JVM).  This makes JDBC the preferred method for connecting to data whenever possible. Hadoop, Hive, and MySQL all run on Java and easily interface with Spark clusters.
#
# In the roadmap for ETL, this is the **Extract and Validate** step:
#
# <img src="https://files.training.databricks.com/images/eLearning/ETL-Part-1/ETL-Process-1.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px; box-shadow: 5px 5px 5px #aaa"/>

# %% [markdown]
# ### Recalling the Design Pattern
#
# Recall the design pattern for connecting to data from the previous lesson:
# <br>
# 1. Define the connection point.
# 2. Define connection parameters such as access credentials.
# 3. Add necessary options.
#
# After adhering to this, read data using `spark.read.options(<option key>, <option value>).<connection_type>(<endpoint>)`.  The JDBC connection uses this same formula with added complexity over what was covered in the lesson.

# %% [markdown]
# Run the cell below to set up your environment.

# %%
# %run "./Includes/Classroom-Setup"

# %% [markdown]
# -sandbox
# Run the cell below to confirm you are using the right driver.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> Each notebook has a default language that appears in upper corner of the screen next to the notebook name, and you can easily switch between languages in a notebook. To change languages, start your cell with `%python`, `%scala`, `%sql`, or `%r`.

# %%
# %scala
// run this regardless of language type
Class.forName("org.postgresql.Driver")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Class[_] = class org.postgresql.Driver
# </div>

# %% [markdown]
# Define your database connection criteria. In this case, you need the hostname, port, and database name.
#
# Access the database `training` via port `5432` of a Postgres server sitting at the endpoint `server1.databricks.training`.
#
# Combine the connection criteria into a URL.

# %%
jdbcHostname = "server1.databricks.training"
jdbcPort = 5432
jdbcDatabase = "training"

jdbcUrl = "jdbc:postgresql://{0}:{1}/{2}".format(jdbcHostname, jdbcPort, jdbcDatabase)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Create a connection properties object with the username and password for the database.

# %%
connectionProps = {
  "user": "readonly",
  "password": "readonly"
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Read from the database by passing the URL, table name, and connection properties into `spark.read.jdbc()`.

# %%
accountDF = spark.read.jdbc(url=jdbcUrl, table="Account", properties=connectionProps)
display(accountDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userID</th><th>screenName</th><th>location</th><th>friendsCount</th><th>followersCount</th><th>description</th><th>insertID</th><th>ETLID</th></tr></thead><tbody><tr><td>711302488427778049</td><td>ILL_04A</td><td>I touched MYNAME 06/09/16</td><td>266</td><td>367</td><td>Doing Cube's job for free.
# «Once 4Minute is always 4Minute»
# Ilhoon's Lady
# 🐝🐝🐝
# NO사랑🌸</td><td>94489285357</td><td>3153</td></tr><tr><td>4325772802</td><td>YoussefJooo8</td><td>أسوان, مصر</td><td>48</td><td>17</td><td>كاائن اليوسف ✋ تعريفه: هو كائن لطيف اوووزعۃ
# youssef ahmed
# Age:19
# from:red sea
# live:in loux
# 2 univiristy
# AAst
# القبطاان ☺
# f.b: jooo Uwk
# #Zamalek
# Smile ツ</td><td>94489285358</td><td>3153</td></tr><tr><td>4805856135</td><td>enda__34</td><td>null</td><td>59</td><td>106</td><td>null</td><td>94489285359</td><td>3153</td></tr><tr><td>859844340025262081</td><td>_beci</td><td>null</td><td>41</td><td>51</td><td>Life goes on 🎈</td><td>94489285360</td><td>3153</td></tr><tr><td>327888219</td><td>freakjawndotcom</td><td>Philadelphia, PA</td><td>2690</td><td>3756</td><td>FreakJawn Inc is about empowering female sex workers, educating cis men, and educating Blue/White collar women who are interested in exploring the sex culture</td><td>94489285361</td><td>3153</td></tr><tr><td>3436712944</td><td>Glynnchen</td><td>Deutschland</td><td>293</td><td>4746</td><td>Untugenden werden toleriert, solange es im Verborgenen verbleibt! Selbstreflektion hat noch keinem geschadet! Versucht es mal selbst!</td><td>94489285362</td><td>3153</td></tr><tr><td>315250717</td><td>DGAFDanielle</td><td>null</td><td>2236</td><td>11900</td><td>21. 011718👶🏻💙 Snapchat: DGAFDaniellee K.LuxeExtensions💋 DiscountCode:LuxeDollDani for 10% off your purchase🗣</td><td>94489285363</td><td>3153</td></tr><tr><td>879857101513695233</td><td>bbalmalnq8</td><td>null</td><td>1068</td><td>1293</td><td>من لا يهتم لامرك لا تهتم لامره الحب جميل والكرامه أجمل</td><td>94489285364</td><td>3153</td></tr><tr><td>230866480</td><td>njwalker_</td><td>null</td><td>334</td><td>570</td><td>It's pretty simple: I luv love</td><td>94489285365</td><td>3153</td></tr><tr><td>929946336992079872</td><td>Sanda05865047</td><td>king Williams town</td><td>287</td><td>19</td><td>null</td><td>94489285366</td><td>3153</td></tr><tr><td>726863101962780672</td><td>VineVineVineV</td><td>null</td><td>0</td><td>26</td><td>See the latest vines!</td><td>94489285367</td><td>3153</td></tr><tr><td>945816595</td><td>janae_payne</td><td>null</td><td>352</td><td>706</td><td>angry at the fact that we can't travel at the speed of light</td><td>94489285368</td><td>3153</td></tr><tr><td>865290712123928577</td><td>mn__881</td><td>null</td><td>2702</td><td>3252</td><td>ماني بنت عّم الصغار الرديين انا لذربين الفعايل بنت عّم👌🌹#غير_صالحه_للعلاقات_الغراميه</td><td>94489285369</td><td>3153</td></tr><tr><td>3299737073</td><td>Ana30361362</td><td>null</td><td>92</td><td>51</td><td>Licenciada en Psicología.Funcionaria en IMAS.  Perraflauta.🐶</td><td>94489285370</td><td>3153</td></tr><tr><td>1428154050</td><td>banh___bao</td><td>Pottawatomi territory</td><td>108</td><td>36</td><td>null</td><td>94489285371</td><td>3153</td></tr><tr><td>710163251242405888</td><td>LisaInTheNow</td><td>Florida, USA</td><td>22602</td><td>41869</td><td>Lisa is a small business expert integrating science with spirituality and her own personal experiences. Lisa helps others create lives of presence and purpose.</td><td>94489285372</td><td>3153</td></tr><tr><td>939742729625587712</td><td>asarkaya_mehmet</td><td>null</td><td>88</td><td>90</td><td>null</td><td>94489285373</td><td>3153</td></tr><tr><td>2920085365</td><td>ruthkroos</td><td>Comunidad de Madrid, España</td><td>856</td><td>997</td><td>Enjoy the Life</td><td>94489285374</td><td>3153</td></tr><tr><td>2615215184</td><td>hzin_10</td><td> </td><td>176</td><td>426</td><td>ان الله معي عندما يرحل كل شي . تغريداتي بالمفضله .</td><td>94489285375</td><td>3153</td></tr><tr><td>188459442</td><td>laurenahooper</td><td>Brighton, UK</td><td>236</td><td>239</td><td>23. Singer-songwriter. Just trying to survive.</td><td>94489285376</td><td>3153</td></tr><tr><td>891883429</td><td>jeffers79491380</td><td>null</td><td>75</td><td>68</td><td>null</td><td>94489285377</td><td>3153</td></tr><tr><td>942038533119754240</td><td>X1tcs16aYfCe7nD</td><td>奈良 県</td><td>76</td><td>39</td><td>可愛い～あいなん大好き☺
#
# あいなんに→かずぽんのだ名付けてもらいました😃
# あいなんを応援してます☺
# 仕事わ→シマダイオート奈良店で車洗車の仕事で働いてます😣
# 僕で良ければ😰→皆さんお友達になってくれる人 フォローお願いします🙇⤵</td><td>94489285378</td><td>3153</td></tr><tr><td>733756300237131776</td><td>kayeldavies</td><td>null</td><td>182</td><td>122</td><td>it's 5 o'clock somewhere 🍸</td><td>94489285379</td><td>3153</td></tr><tr><td>4135423048</td><td>rdgmn1</td><td>Cabuçu, Nova Iguaçu </td><td>275</td><td>133</td><td>Veja a minha loucura🙃</td><td>94489285380</td><td>3153</td></tr><tr><td>919921149705846785</td><td>cncosmitodo</td><td>null</td><td>305</td><td>2378</td><td>porque tú me miras y yo siento lo mismo que tú🌙</td><td>94489285381</td><td>3153</td></tr><tr><td>250090044</td><td>Gnesner</td><td>null</td><td>4</td><td>3</td><td>null</td><td>94489285382</td><td>3153</td></tr><tr><td>726764438594969600</td><td>deniizzzx</td><td>Bursa</td><td>73</td><td>1571</td><td>gazapizm'kezzo
# XXII.VIII'❣</td><td>94489285383</td><td>3153</td></tr><tr><td>2824998708</td><td>lilpumpz</td><td>we do not own content | parody</td><td>5812</td><td>39860</td><td>@vantablvck || esskeetit || business: @ViralSocialCo</td><td>94489285384</td><td>3153</td></tr><tr><td>941856004370771969</td><td>Sabrina08429704</td><td>#TEAMSIL#SDV #1DDrive #ツᎷᎶᏔѴツ </td><td>2315</td><td>2101</td><td>🐾 Se falam de mim pelas costas, é sinal de que minha vida é bem mais interessante do que a delas.🐾
#  🕊  @detremura  🕊</td><td>94489285385</td><td>3153</td></tr><tr><td>3312861829</td><td>iD7M7</td><td>null</td><td>4997</td><td>640</td><td>null</td><td>94489285386</td><td>3153</td></tr><tr><td>394751004</td><td>manueldelapista</td><td>Detrás de ti ¬¬</td><td>207</td><td>144</td><td>null</td><td>94489285387</td><td>3153</td></tr><tr><td>42782342</td><td>emajus</td><td>Western US</td><td>1059</td><td>408</td><td>Maker of Beautiful Things and SOphisticated Interstate Playboy</td><td>94489285388</td><td>3153</td></tr><tr><td>805146989453332480</td><td>oliviakbarber</td><td>null</td><td>23</td><td>17</td><td>null</td><td>94489285389</td><td>3153</td></tr><tr><td>1649404832</td><td>xf_jaguar</td><td>null</td><td>266</td><td>53</td><td>null</td><td>94489285390</td><td>3153</td></tr><tr><td>873527886237450240</td><td>hope94love04</td><td>대한민국 서울</td><td>25</td><td>26</td><td>우리 호석이 오빠 항상 꽃 길만 걷기 바래요...🐎❣️２０１８년도 화이팅 ! 호석이 오빠 응원 2 년째🐴💕💕</td><td>94489285391</td><td>3153</td></tr><tr><td>450237391</td><td>Sachiel_tt_1179</td><td>null</td><td>5640</td><td>5486</td><td>阪神タイガース大好き。 気軽に絡んでくださいお待ちしています！サヨナラはブロックで。最近botも起動しました。→ダミーシステムで起動中。 #阪神／ #エヴァ／ #艦これ（ブルネイ泊地）</td><td>94489285392</td><td>3153</td></tr><tr><td>3391885011</td><td>TekaeLala</td><td>null</td><td>1502</td><td>1882</td><td>' Não me vejo mais sem vs , vínya ❤  10.11.15 👧</td><td>94489285393</td><td>3153</td></tr><tr><td>295840783</td><td>chloeemery1</td><td>Liverpool</td><td>487</td><td>279</td><td>NEW TWITTER- ChloeEmery_x</td><td>94489285394</td><td>3153</td></tr><tr><td>4824825454</td><td>tiago5522</td><td>null</td><td>261</td><td>160</td><td>Boas.
# http://curiouscat.me/Tiago1</td><td>94489285395</td><td>3153</td></tr><tr><td>71311876</td><td>mikeroll14me</td><td>Baton Rouge, LA</td><td>164</td><td>412</td><td>I’m out here on a mission and I’m all alone. I’m far from where I’m going and

# %% [markdown]
# ## Exercise 1: Parallelizing JDBC Connections
#
# The command above was executed as a serial read through a single connection to the database. This works well for small data sets; at scale, parallel reads are neccesary for optimal performance.
#
# See the [Managing Parallelism](https://docs.azuredatabricks.net/spark/latest/data-sources/sql-databases.html#manage-parallelism) section of the Databricks documentation.

# %% [markdown]
# -sandbox
# ### Step 1: Find the Range of Values in the Data
#
# Parallel JDBC reads entail assigning a range of values for a given partition to read from. The first step of this divide-and-conquer approach is to find bounds of the data.
#
# Calculate the range of values in the `insertID` column of `accountDF`. Save the minimum to `dfMin` and the maximum to `dfMax`.  **This should be the number itself rather than a DataFrame that contains the number.**  Use `.first()` to get a Scala or Python object.
#
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** See the `min()` and `max()` functions in Python `pyspark.sql.functions` or Scala `org.apache.spark.sql.functions`.

# %%
# TODO
from pyspark.sql.functions import max, min

dfMin = accountDF.select(min("insertID")).first()[0]
dfMax = accountDF.select(max("insertID")).first()[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfMin
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">22</span><span class="ansired">]: </span>0</div>

# %%
# TEST - Run this cell to test your solution

dbTest("ET1-P-04-01-01", 0, dfMin)
dbTest("ET1-P-04-01-02", 214748365087, dfMax)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# -sandbox
# ### Step 2: Define the Connection Parameters.
#
# <a href="https://docs.azuredatabricks.net/spark/latest/data-sources/sql-databases.html#manage-parallelism" target="_blank">Referencing the documentation,</a> define the connection parameters for this read.  Use 12 partitions.
#
# Save the results to `accountDFParallel`.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> Setting the column for your parallel read introduces unexpected behavior due to a bug in Spark. To make sure Spark uses the capitalization of your column, use `'"insertID"'` for your column. <a href="https://github.com/apache/spark/pull/20370#issuecomment-359958843" target="_blank"> Monitor the issue here.</a>

# %%
# TODO
accountDFParallel = spark.read.jdbc(
  url = jdbcUrl,
  table = "Account",
  column = '"insertID"',
  lowerBound = dfMin,
  upperBound = dfMax,
  numPartitions = 12,
  properties = connectionProps
)

display(accountDFParallel)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userID</th><th>screenName</th><th>location</th><th>friendsCount</th><th>followersCount</th><th>description</th><th>insertID</th><th>ETLID</th></tr></thead><tbody><tr><td>899279937558818817</td><td>pui_kookie</td><td>ประเทศไทย</td><td>38</td><td>0</td><td>💕บุคคลผู้เเต่งฟิคบังทัน💞💞💞</td><td>17179873995</td><td>3153</td></tr><tr><td>947960237226467328</td><td>VictorM53727258</td><td>null</td><td>121</td><td>5</td><td>null</td><td>17179873996</td><td>3153</td></tr><tr><td>718773313468768258</td><td>ntarasia06</td><td>Bhubaneshwar, India</td><td>19</td><td>45</td><td>null</td><td>17179873997</td><td>3153</td></tr><tr><td>4334300787</td><td>dehavenick5</td><td>null</td><td>561</td><td>620</td><td>fly with me ✈️Maddie ❤️</td><td>17179873998</td><td>3153</td></tr><tr><td>772105712268902404</td><td>cabellyouth</td><td>Cabello stan</td><td>1253</td><td>2180</td><td>to her. • Camila follow's</td><td>17179873999</td><td>3153</td></tr><tr><td>920579990743166976</td><td>I_lover_ss</td><td>샌즈 방 침대 구석!</td><td>67</td><td>63</td><td>언더테일 / 드림 / 그림 / 마음요정 / 말랑한 사람 / 미성년자 / 언더테일 스포 ⭕ / 헤더는 료시님께서 그려주신 너무 너무 예쁜 샌즈아이~~~~!!💝🌹✨/ #샌즈아이 / ❄✨내사랑 샌즈✨❄ ☞@sans_for_i 세상에서 당신만큼 어여쁜 이는 보지못했어요.</td><td>17179874000</td><td>3153</td></tr><tr><td>446815193</td><td>MayLoves5H</td><td>México</td><td>299</td><td>1480</td><td>I love Fifth Harmony with all my heart💞
# #PSATourMonterrey 11/10/2017 ❤❤❤❤
# Dinah follows me 14/11/2017</td><td>17179874001</td><td>3153</td></tr><tr><td>2998459529</td><td>giimarote_</td><td>São Paulo, Brasil</td><td>180</td><td>1323</td><td>Vivo pelo campeão dos campeões - NÃO AO FUTEBOL MODERNO ATÉ APÓS A MORTE!</td><td>17179874002</td><td>3153</td></tr><tr><td>741465963351158784</td><td>barrildemil</td><td>Salvador, Brasil</td><td>989</td><td>1787</td><td>Um paradoxo do pretérito imperfeito, complexo com a teoria da relatividade. Fluente em errar na vida. Flamenguista.</td><td>17179874003</td><td>3153</td></tr><tr><td>947939851537670144</td><td>TeBancoMuchoFV</td><td>Argentina</td><td>509</td><td>123</td><td>A la gente buena les pasa cosas buenas, @flor_vigna ❤ #PaulaAmoedoAlBailando2018</td><td>17179874004</td><td>3153</td></tr><tr><td>916694074375196674</td><td>K_Camisa8</td><td>Uesf</td><td>262</td><td>177</td><td>13 Anos♡-
# Botafoguense-🏴🏳
# Uesf
# Um amor de pessoa❤
# @Ribeiro_milly5
# http://curiouscat.me/Kaua_bfr</td><td>17179874005</td><td>3153</td></tr><tr><td>2275455651</td><td>majucostad</td><td>Belo Horizonte, Brasil</td><td>564</td><td>493</td><td>null</td><td>17179874006</td><td>3153</td></tr><tr><td>741465963351158784</td><td>barrildemil</td><td>Salvador, Brasil</td><td>989</td><td>1787</td><td>Um paradoxo do pretérito imperfeito, complexo com a teoria da relatividade. Fluente em errar na vida. Flamenguista.</td><td>17179874007</td><td>3153</td></tr><tr><td>67227742</td><td>holdtolight</td><td>null</td><td>1088</td><td>698</td><td>null</td><td>17179874008</td><td>3153</td></tr><tr><td>1202688072</td><td>Robin_cru</td><td>null</td><td>2</td><td>3</td><td>null</td><td>17179874009</td><td>3153</td></tr><tr><td>705557038634504192</td><td>iadoreartwork</td><td>masterpiece 🥀</td><td>4870</td><td>30782</td><td>earth without art is just "eh"</td><td>17179874010</td><td>3153</td></tr><tr><td>62668558</td><td>mikubell</td><td>青い森の黒い石</td><td>1042</td><td>1331</td><td>本州最北端な県のDTPオペ</td><td>17179874011</td><td>3153</td></tr><tr><td>3280748060</td><td>alcoda_2</td><td>with 아델(4.14) 유(9.3) 비키(4.2)</td><td>223</td><td>200</td><td>@yoonn_dr : 그림계</td><td>17179874012</td><td>3153</td></tr><tr><td>885715113755385856</td><td>yehet0112</td><td>경수시 사랑동</td><td>244</td><td>3</td><td>긔여운거 사랑하는 사람`0`
# 경수사랑해
# 토비오사랑해애애</td><td>17179874013</td><td>3153</td></tr><tr><td>3029763866</td><td>shabrawya7</td><td>null</td><td>1353</td><td>595</td><td>null</td><td>17179874014</td><td>3153</td></tr><tr><td>1250903839</td><td>syunsaimanyou</td><td>null</td><td>29</td><td>41</td><td>毎度ありがとうございます。
#
# 博多中洲　旬菜万葉では、地元の食材や旬の味を活かしたお料理をお出ししております。
# 博多中洲へお越しの際は、ぜひ、博多中洲　旬菜万葉へお運びください。
# スタッフ一同、心より、お待ちしております。</td><td>17179874015</td><td>3153</td></tr><tr><td>85429951</td><td>CarlaSil_</td><td>The moon</td><td>602</td><td>981</td><td>23|IPG HPAO🏨|ADeca| Vinotinto & Barça|IG CarlaSil_|Snap: Carlasil07 |Todo lo que digas puede ser utilizado en tu contra</td><td>17179874016</td><td>3153</td></tr><tr><td>235179178</td><td>jatinahuja100</td><td>India</td><td>1642</td><td>120</td><td>jatinahuja8046@gmail.com</td><td>17179874017</td><td>3153</td></tr><tr><td>914568374155464706</td><td>Andrea20448228</td><td>null</td><td>7</td><td>0</td><td>null</td><td>17179874018</td><td>3153</td></tr><tr><td>846526972788326402</td><td>Itsnotkvylee480</td><td>null</td><td>264</td><td>273</td><td>🦂19.</td><td>17179874019</td><td>3153</td></tr><tr><td>336278251</td><td>GiovanniZimmer</td><td>Gaspar, Brasil</td><td>495</td><td>898</td><td>+ 18, @Flamengo</td><td>17179874020</td><td>3153</td></tr><tr><td>2985929188</td><td>SkyDi4mond</td><td>America</td><td>11</td><td>35</td><td>Welcome to my little portion of twitter! I'm a teen gamer who loves Overwatch & CS: GO.</td><td>17179874021</td><td>3153</td></tr><tr><td>873051730560172032</td><td>GreenGirlNZ65</td><td>Hamilton City, New Zealand</td><td>276</td><td>34</td><td>Home Based Child Care Educator. Loving life.</td><td>17179874022</td><td>3153</td></tr><tr><td>935522128002248704</td><td>Sonia_FBPE</td><td>Bucks, UK, Europe</td><td>1659</td><td>1656</td><td>Citizen of Europe. No Tribal politics, my party is FBPE! supporting all Pro EU and those fighting for a #FinalSay</td><td>17179874023</td><td>3153</td></tr><tr><td>561735432</td><td>theawkwardtsar</td><td>Maine, USA</td><td>1204</td><td>847</td><td>BOT-SLAYER! If U have #s @ the end of your handle you're suspect. RESIST IMPEACH FBR Ally to ALL marginalized peeps. Trump Trolls/Listers will be blocked.</td><td>17179874024</td><td>3153</td></tr><tr><td>378486719</td><td>gxrb</td><td>京都⇔大阪</td><td>548</td><td>290</td><td>写真(最近は撮影会でポートレートの練習中)。カメラ(ニコンメイン。他にペンタックス、オリンパス、ソニー、富士フイルムなど)。カメラは浮気性ですが、モデルさんは竹歳みずほさん(←アイドル活動もされてます。AMER+メンバー。)が大好きで、三代目「チームみぃしゅか」隊長☺️</td><td>17179874025</td><td>3153</td></tr><tr><td>3928768940</td><td>SnoopingAnthro</td><td>Everywhere USA</td><td>978</td><td>748</td><td>#Liberty Lover * Lady Actor Turned Teacher & Anthropologist * Snoops Inside Hollywood, Education & Culture * #Constitution #MAGA
# FB @ETnow  @CharlieKirk11</td><td>17179874026</td><td>3153</td></tr><tr><td>819316719592292353</td><td>yo_favriri</td><td>Ohio, USA</td><td>354</td><td>318</td><td>♎09.29♎ 🎀snapchat👻: itsdena 🎀 ATL✈️BAMA✈️OH✈️⁉️</td><td>17179874027</td><td>3153</td></tr><tr><td>96605410</td><td>nazzos</td><td>Rio de Janeiro</td><td>269</td><td>376</td><td>Salve-se quem quiser.</td><td>17179874028</td><td>3153</td></tr><tr><td>105696219</td><td>futubby</td><td>null</td><td>106</td><td>65</td><td>always keep the faith , future together.</td><td>17179874029</td><td>3153</td></tr><tr><td>2158032990</td><td>LondonAeri</td><td>FL</td><td>154</td><td>102</td><td>❅◦✰⇢ｆａｉｒｙ ｐｒｉｎｃｅ↞❦ ◌ ❊</td><td>17179874030</td><td>3153</td></tr><tr><td>37024642</td><td>buoy44065</td><td>New York Harbor Entrance</td><td>0</td><td>40</td><td>Real-time wind, wave, and meteorological observations from the New York Harbor buoy.</td><td>17179874031</td><td>3153</td></tr><tr><td>183502243</td><td>SUZURAN0303</td><td>田園地帯</td><td>852</td><td>497</td><td>植物を育てるのが好きな主婦です。いつも食事のメニューに悩んでいます。</td><td>17179874032</td><td>3153</td></tr><tr><td>887510999678537728</td><td>Anood_J52</td><td>null</td><td>50</td><td>32</td><td>52🌟❤❤.</td><td>17179874033</td><td>3153</td></tr><tr><td>4902200794</td><td>Crowenscrown</td><td>Georgia country.

# %%
# TEST - Run this cell to test your solution
dbTest("ET1-P-04-02-01", 12, accountDFParallel.rdd.getNumPartitions())

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ### Step 3: Compare the Serial and Parallel Reads
#
# Compare the two reads with the `%timeit` function.

# %% [markdown]
# Display the number of partitions in each DataFrame by running the following:

# %%
print(accountDF.rdd.getNumPartitions())
print(accountDFParallel.rdd.getNumPartitions())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1
# 12
# </div>

# %% [markdown]
# Invoke `%timeit` followed by calling a `.describe()`, which computes summary statistics, on both `accountDF` and `accountDFParallel`.

# %%
# %timeit accountDF.describe()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1 loops, best of 3: 4.22 s per loop
# </div>

# %%
# %timeit accountDFParallel.describe()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1 loops, best of 3: 3.56 s per loop
# </div>

# %% [markdown]
# What is the difference between serial and parallel reads?  Note that your results vary drastically depending on the cluster and number of partitions you use

# %% [markdown]
# ## Review
#
# **Question:** What is JDBC?
# **Answer:** JDBC stands for Java Database Connectivity, and is a Java API for connecting to databases such as MySQL, Hive, and other data stores.
#
# **Question:** How does Spark read from a JDBC connection by default?
# **Answer:** With a serial read.  With additional specifications, Spark conducts a faster, parallel read.  Parallel reads take full advantage of Spark's distributed architecture.
#
# **Question:** What is the general design pattern for connecting to your data?
# **Answer:** The general design patter is as follows:
# 0. Define the connection point
# 0. Define connection parameters such as access credentials
# 0. Add necessary options such as for headers or paralleization

# %% [markdown]
# ## Next Steps
#
# Start the next lesson, [Applying Schemas to JSON Data]($./05-Applying-Schemas-to-JSON-Data ).

# %% [markdown]
# ## Additional Topics & Resources
#
# **Q:** My tool can't connect via JDBC.  Can I connect via <a href="https://en.wikipedia.org/wiki/Open_Database_Connectivity" target="_blank">ODBC instead</a>?
# **A:** Yes.  The best practice is generally to use JDBC connetions wherever possible since Spark runs on the JVM.  In cases where JDBC is either not supported or is less performant, use the Simba ODBC driver instead.  See <a href="https://docs.azuredatabricks.net/user-guide/bi/jdbc-odbc-bi.html#step-1-download-and-install-a-jdbc-odbc-driver" target="_blank">the Databricks documentation on connecting BI tools</a> for more details.
